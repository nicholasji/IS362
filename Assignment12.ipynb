# %% [markdown]
# ## Assignment – Web APIs Week 12
# ### Nick Ileczko

# %%
#API KEY : dcf48edd81e34ee08602b5586e0f4d08
# https://api.nytimes.com/svc/mostpopular/v2/mostviewed/Technology/30.json?
import pandas as pd
import numpy as np
import json
import sys
import urllib.request

# %% [markdown]
# Query: Most viewed Technology articles in the last 30 days

# %%
api_key = 'dcf48edd81e34ee08602b5586e0f4d08'
url = 'https://api.nytimes.com/svc/mostpopular/v2/mostviewed/Technology/30.json?'
string = url+'&api-key='+api_key

response = str(urllib.request.urlopen(string).read(), 'utf-8')
data = json.loads(response)
popular = json_normalize(data['results'])
popular
# Out:
#                                              abstract  \
# 0   Nearly all big tech companies have an artifici...
# 1   Your smartphone is not deliberately losing spe...
# 2   Apple’s newest iPhone takes a big leap from pa...
# 3   It was another fiasco that the social media co...
# 4   American tech companies positioned themselves ...
# 5   The Alphabet unit says it expects to allow pas...
# 6   Google and others, fighting for a small pool o...
# 7   Coverage of President Trump may eclipse that o...
# 8   Celebrity endorsements are helping start-ups r...
# 9   In Silicon Valley, small companies used to uns...
# 10  Tech firms are deploying sophisticated marketi...
# 11  As the world’s moneyed princes, dictators and ...
# 12  The incels, or involuntary celibates, violated...
# 13  Pieter Abbeel, a Berkeley professor, is part o...
# 14  The bidders came from 43 U.S. states, as well ...
# 15  While Amazon appears interested in exploring t...
# ...
